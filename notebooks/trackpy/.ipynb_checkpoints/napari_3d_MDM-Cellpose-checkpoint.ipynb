# %% [markdown]
# # Napari demo

# %% [markdown]
# ## Import packages

# %% [markdown]
# Click on **[this link](../desktop)** to open a new window where napari will be visible. Only required for mybinder

# %%
import os
os.environ['DISPLAY'] = ':1.0'

import warnings
warnings.filterwarnings('ignore')
import napari
import skimage
import matplotlib.pyplot as plt
import numpy as np
import requests
import skimage.feature
import pandas as pd
import trackpy
import pims
import numpy as np
import dask
import dask.array
import warnings
import cupy as cp
import glob
import Libraries
import sys
sys.path.insert(0,'/home/jmamede/scripts')
# from support_pla import othercolor, cell_mask, multiply, rebin
from support_pla import cellpose_mask,cellpose_model
import trackpy as tp
from cellpose import io as iocp
from cellpose import plot,utils

# %%
# %gui qt5

# %% [markdown]
# ## Download the data from Zenodo.

# %% [markdown]
# This dataset is a time-lapse of a zebrafish embry acquired by confocal microscopy. See [here](https://zenodo.org/record/1211599#.XZSnAOf7TOR) for more details.

# %%
__author__ = """João Mamede"""
__email__ = "jmamede@rush.edu"


# filelist = glob.glob('/run/media/jmamede/Joao/CAruby/20201208caruby/*.ome.tiff')
filelist = glob.glob('/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/*ome.tiff')
filelist.sort()

# all = []
filelist
all = Libraries.stitch(filelist,9,5)
red = all[1:-2:3]
green = all[:-3:3]
blue = all[2:-1:3]
#can't reshape I don't know why, resclicing was the only way I found



#DETAIL IS HERE!!!!
rgb = dask.array.stack([red,blue,green],axis=0)
# Out:
# 0 odd ['/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v01_PRJ.ome.tiff', '/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v02_PRJ.ome.tiff', '/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v03_PRJ.ome.tiff', '/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v04_PRJ.ome.tiff', '/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v05_PRJ.ome.tiff', '/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v06_PRJ.ome.tiff', '/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v07_PRJ.ome.tiff', '/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v08_PRJ.ome.tiff', '/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v09_PRJ.ome.tiff']
# /run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v01_PRJ.ome.tiff
# /run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v02_PRJ.ome.tiff
# /run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v03_PRJ.ome.tiff
# /run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v04_PRJ.ome.tiff
# /run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v05_PRJ.ome.tiff
# /run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v06_PRJ.ome.tiff
# /run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v07_PRJ.ome.tiff
# /run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v08_PRJ.ome.tiff
# /run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v09_PRJ.ome.tiff
# even ['/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v18_PRJ.ome.tiff'
#  '/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v17_PRJ.ome.tiff'
#  '/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v16_PRJ.ome.tiff'
#  '/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v15_PRJ.ome.tiff'
#  '/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v14_PRJ.ome.tiff'
#  '/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v13_PRJ.ome.tiff'
#  '/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v12_PRJ.ome.tiff'
#  '/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v11_PRJ.ome.tiff'
#  '/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v10_PRJ.ome.tiff']
# /run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v18_PRJ.ome.tiff
# /run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v17_PRJ.ome.tiff
# /run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v16_PRJ.ome.tiff
# /run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v15_PRJ.ome.tiff
# /run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v14_PRJ.ome.tiff
# /run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v13_PRJ.ome.tiff
# /run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v12_PRJ.ome.tiff
# /run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v11_PRJ.ome.tiff
# /run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v10_PRJ.ome.tiff
# 2 odd ['/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v19_PRJ.ome.tiff', '/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v20_PRJ.ome.tiff', '/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v21_PRJ.ome.tiff', '/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v22_PRJ.ome.tiff', '/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v23_PRJ.ome.tiff', '/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v24_PRJ.ome.tiff', '/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v25_PRJ.ome.tiff', '/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v26_PRJ.ome.tiff', '/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v27_PRJ.ome.tiff']
# /run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v19_PRJ.ome.tiff
# /run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v20_PRJ.ome.tiff
# /run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v21_PRJ.ome.tiff
# /run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v22_PRJ.ome.tiff
# /run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v23_PRJ.ome.tiff
# /run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v24_PRJ.ome.tiff
# /run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v25_PRJ.ome.tiff
# /run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v26_PRJ.ome.tiff
# /run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v27_PRJ.ome.tiff
# even ['/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v36_PRJ.ome.tiff'
#  '/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v35_PRJ.ome.tiff'
#  '/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v34_PRJ.ome.tiff'
#  '/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v33_PRJ.ome.tiff'
#  '/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v32_PRJ.ome.tiff'
#  '/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v31_PRJ.ome.tiff'
#  '/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v30_PRJ.ome.tiff'
#  '/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v29_PRJ.ome.tiff'
#  '/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v28_PRJ.ome.tiff']
# /run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v36_PRJ.ome.tiff
# /run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v35_PRJ.ome.tiff
# /run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v34_PRJ.ome.tiff
# /run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v33_PRJ.ome.tiff
# /run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v32_PRJ.ome.tiff
# /run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v31_PRJ.ome.tiff
# /run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v30_PRJ.ome.tiff
# /run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v29_PRJ.ome.tiff
# /run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v28_PRJ.ome.tiff
# 4 odd ['/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v37_PRJ.ome.tiff', '/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v38_PRJ.ome.tiff', '/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v39_PRJ.ome.tiff', '/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v40_PRJ.ome.tiff', '/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v41_PRJ.ome.tiff', '/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v42_PRJ.ome.tiff', '/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v43_PRJ.ome.tiff', '/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v44_PRJ.ome.tiff', '/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v45_PRJ.ome.tiff']
# /run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v37_PRJ.ome.tiff
# /run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v38_PRJ.ome.tiff
# /run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v39_PRJ.ome.tiff
# /run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v40_PRJ.ome.tiff
# /run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v41_PRJ.ome.tiff
# /run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v42_PRJ.ome.tiff
# /run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v43_PRJ.ome.tiff
# /run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v44_PRJ.ome.tiff
# /run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/M13d_iGFPCAru3_01062021_PBN_VitC_Rutin_NH4Cl_nuc_Vera_pump_v45_PRJ.ome.tiff

# %%
rgb
# Out:
# dask.array<stack, shape=(3, 122, 5120, 9216), dtype=uint16, chunksize=(1, 1, 1024, 1024), chunktype=numpy.ndarray>

# %% [markdown]
# ## Image import and plotting

# %% [markdown]
# We rescale the image in z by a factor of 5 to clearly show all features. We only keep the later time points for the demo.

# %%
# ##USE THIS ON MYBINDER (RESIZED IMAGE AND FEWER TIME POINTS
# '''image_import = skimage.external.tifffile.TiffFile('Sample/cxcr4aMO2_290112.lsm') 
# time_min = 100
# time_max = 130
# image_time = np.zeros((time_max-time_min,22,256,256))
# for t in range(time_min, time_max):
#     image_time[t-time_min,:,:,:] = image_import.asarray(key=2*np.arange(t*44,(t+1)*44))[::2,::2,::2]
# '''  

# ##USE THIS ON A REGULAR COMPUTER
# image_time = skimage.io.imread('Sample/cxcr4aMO2_290112.lsm', 
#                                plugin='tifffile')
# image_time = image_time[0,100:150,:,:,:]

# %% [markdown]
# ## Nuclei detection
# We use a simple gaussian filtering followed by local maxima detection to find all the nuclei and create an array with time, x, y,z positions.

# %%
model_nuc = cellpose_model(GPU=True,model_type='nuclei')
# Out:
# ** CUDA version installed and working. **
# >>>> using GPU
# cellpose_residual_on_style_on_concatenation_off

# %%
nuclei_masks = cellpose_mask(blue[0].compute(),model_nuc
#                             ,size=2500
                            ,flow_threshold=1.0,size=0,diam=50,cell_prob=-1.2,
                             _bin=False,
                           )
# Out:
# processing 1 image(s)
# time spent: running network 21.19s; flow+mask computation 18.68
# estimated masks for 1 image(s) in 40.97 sec
# >>>> TOTAL TIME 40.97 sec

# %%
plt.imshow(nuclei_masks)

# %%
import scipy.ndimage as ndi

# %%
# coords = ndi.measurements.center_of_mass(blue[0].compute(),nuclei_masks ,np.arange(1,nuclei_masks .max()+1))

# %%
all_dots = []
labels = np.zeros((blue.shape))
for i in range(blue.shape[0]):
    print(i)
    nuclei_masks = cellpose_mask(blue[i].compute(),model_nuc
#                             ,size=2500
                            ,flow_threshold=1.2,size=0,diam=50,cell_prob=-1.2,
                             _bin=False,
                           )
    coords = np.stack(
                ndi.measurements.center_of_mass(
                    blue[i].compute(),nuclei_masks ,np.arange(1,nuclei_masks .max()+1))
    )
    labels[i,:,:] = nuclei_masks
    all_dots.append(np.stack((i*np.ones(coords.shape[0]),
                       coords[:,0],coords[:,1]),axis =1))
spots = np.concatenate(all_dots)
# spots = np.asarray(all_dots)
# Out:
# 0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-447b9039e85c> in <module>
#       3 for i in range(blue.shape[0]):
#       4     print(i)
# ----> 5     nuclei_masks = cellpose_mask(blue[i].compute(),model_nuc
#       6 #                             ,size=2500
#       7                             ,flow_threshold=1.2,size=0,diam=50,cell_prob=-1.2,
#
# NameError: name 'model_nuc' is not defined

# %%
# spots = np.concatenate(all_dots)
spots_pd = pd.DataFrame(spots,columns=['frame','x','y'])

# %%
store.close()

# %%
spots = pd.read_hdf('/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/Nuclei_spots3.h5')

# %%
# store = pd.HDFStore('/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/Nuclei_spots3.h5')
# store['df'] = spots_pd
# store.close()

# %%
spots
# Out:
#         frame            x            y
# 0         0.0     2.978210  7809.774904
# 1         0.0     5.803889  4709.715707
# 2         0.0     9.232053  4080.731574
# 3         0.0     9.128707  6866.842092
# 4         0.0    12.317972  6304.847350
# ...       ...          ...          ...
# 230078  121.0  5108.168657  3058.524973
# 230079  121.0  5108.508426  6699.743452
# 230080  121.0  5113.261983  3746.941546
# 230081  121.0  5113.304121  5098.750864
# 230082  121.0  5111.782635  8512.212526
#
# [230083 rows x 3 columns]

# %%
import tifffile as tf
tf.imwrite('/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/labels.tiff', labels,
                       compress='LZMA',
                       photometric='minisblack',
                        #datetime= True,
                        metadata={'axes': 'TYX'},
                        contiguous=False)

# %%
v = napari.Viewer(ndisplay=2)
v.add_image(blue,
            # rgb=True,
#             contrast_limits=[rmin,rmax],
            blending='additive',
#             colormap='green',
            name='DAPI',#, is_pyramid=False
                 )

v.add_points(spots,face_color='red',opacity=0.5,size=15)
# v.add_shapes(all_traj, shape_type='path',edge_color='grey')
# Out:
# <Points layer 'spots' at 0x7fafd0b451d0>

# %%
import trackpy as tp

# f = tp.locate(green[0].compute(),diameter=5,minmass=10000,engine='numba')

green
# Out:
# dask.array<getitem, shape=(122, 5120, 9216), dtype=uint16, chunksize=(1, 1024, 1024), chunktype=numpy.ndarray>

# %%
igfp = green.compute()

# %%
red
# Out:
# array([[[1670, 1667, 1716, ..., 1378, 2319, 2293],
#         [1677, 1675, 1721, ..., 1385, 2338, 2313],
#         [1555, 1553, 1944, ..., 1723, 2135, 1784],
#         ...,
#         [2244, 2249, 2314, ..., 1474, 2435, 1257],
#         [1475, 1470, 2075, ..., 1513, 1835, 1281],
#         [2240, 2249, 1332, ..., 1544, 1465, 1728]],
#
#        [[1309, 1310, 1604, ..., 2425, 2011, 1368],
#         [1309, 1311, 1604, ..., 2439, 2022, 1359],
#         [1769, 1770, 2007, ..., 2685, 2574, 1522],
#         ...,
#         [1349, 1341, 1660, ..., 2204, 3149, 1273],
#         [1162, 1165, 1550, ..., 1467, 2993, 1440],
#         [1240, 1246, 2645, ..., 1300, 1507, 1854]],
#
#        [[1489, 1491, 1323, ..., 1496, 1924, 1426],
#         [1486, 1487, 1332, ..., 1501, 1923, 1424],
#         [1424, 1429, 1481, ..., 1095, 1223, 1835],
#         ...,
#         [1179, 1186, 1669, ..., 1423,  967, 1046],
#         [1213, 1219, 1696, ..., 1744, 1179, 1170],
#         [1730, 1731, 1253, ..., 1371, 1159, 1660]],
#
#        ...,
#
#        [[2297, 2279, 2393, ..., 1305, 1363, 1670],
#         [2305, 2288, 2394, ..., 1301, 1360, 1671],
#         [2854, 2858, 2323, ..., 1363, 1454, 2232],
#         ...,
#         [1436, 1448, 1372, ..., 1842, 2011, 2595],
#         [1485, 1475, 2903, ..., 1434, 1565, 1200],
#         [1894, 1879, 2479, ..., 1936, 2075, 1390]],
#
#        [[2097, 2093, 2536, ..., 1521, 1613, 1425],
#         [2107, 2105, 2535, ..., 1522, 1613, 1424],
#         [1783, 1778, 1615, ..., 1557, 1692, 1168],
#         ...,
#         [4554, 4598, 5038, ..., 2306, 2523, 1918],
#         [4667, 4713, 3510, ..., 1870, 1528, 1448],
#         [4373, 4349, 3105, ..., 1919, 2002, 1269]],
#
#        [[2922, 2912, 2675, ..., 1715, 2120, 2118],
#         [2915, 2907, 2669, ..., 1720, 2114, 2119],
#         [2530, 2529, 1853, ..., 1689, 1863, 1630],
#         ...,
#         [2896, 2880, 2208, ..., 1288, 1605, 1968],
#         [1844, 1832, 2079, ..., 1519, 1744, 1658],
#         [1543, 1560, 2407, ..., 1631, 1847, 1590]]], dtype=uint16)

# %%
red = red.compute()

# %%
blue = blue.compute()

# %%
list(range(f_igfp.frame.max()+1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-849c6f83ff09> in <module>
# ----> 1 list(range(f_igfp.frame.max()+1))
#
# NameError: name 'f_igfp' is not defined

# %%
f_igfp = tp.batch(igfp[:3], 9, separation=3, minmass=25000,engine='numba');

all_dots = []
for t in range(f_igfp.frame.max()+1):
    coords = f_igfp[f_igfp.frame == t]
    newloc = np.stack((t*np.ones(coords.shape[0]),
                       coords['y'],coords['x']),axis =1)
    all_dots.append(newloc)
spots = np.concatenate(all_dots)
# Out:
# Frame 2: 31049 features

# %%
v = napari.Viewer(ndisplay=2)
v.add_image(igfp[:3],
            # rgb=True,
#             contrast_limits=[rmin,rmax],
            blending='additive',
#             colormap='green',
            name='iGFP',#, is_pyramid=False
                 )

v.add_points(spots,face_color='red',opacity=0.5,size=3)
# Out:
# <Points layer 'spots' at 0x7f1881240490>

# %%
spots
# Out:
#         frame           x           y
# 0         0.0    0.322540  845.798622
# 1         0.0    0.628561  510.062211
# 2         0.0    0.999831  441.943229
# 3         0.0    0.988639  743.678999
# 4         0.0    1.334036  682.814968
# ...       ...         ...         ...
# 230078  121.0  553.214666  331.238255
# 230079  121.0  553.251463  725.582216
# 230080  121.0  553.766273  405.793769
# 230081  121.0  553.770836  552.194719
# 230082  121.0  553.606059  921.872617
#
# [230083 rows x 3 columns]

# %%
f_igfp = tp.batch(igfp, 9, separation=3, minmass=25000,engine='numba', processes='auto');
# Out:
# Frame 121: 3964 features

# %%
# t = tp.link(f_igfp, 7, memory=1)
# # tp.subpx_bias(f)
# with trackpy.PandasHDFStore('/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/TrajectoriesiGFPparticles_good.h5') as s:
#     s.put(t)

# %%
store = pd.HDFStore('/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/spots_igfp_good.h5')
store['df'] = f_igfp
store.close()

# %%
f_caruby = tp.batch(red, 9, separation=3, minmass=20000,engine='numba', processes='auto');
# Out:
# Frame 121: 2008 features

# %%
t = tp.link(f_caruby, 9, memory=2)
with trackpy.PandasHDFStore('/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/Trajectories_caruby_particles.h5') as s:
    s.put(t)
# Out:
# Frame 121: 8527 trajectories present.

# %%
store = pd.HDFStore('/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/spots_caru3_good.h5')
store['df'] = f_caruby
store.close()

# %%
all_dots = []

for t in range(green.shape[0]):
    coords = f_igfp[f_igfp.frame == t]
    newloc = np.stack((t*np.ones(coords.shape[0]),
                       coords['y'],coords['x']),axis =1)
    all_dots.append(newloc)
spots_igfp = np.concatenate(all_dots)


all_dots = []

for t in range(red.shape[0]):
    coords = f_caruby[f_caruby.frame == t]
    newloc = np.stack((t*np.ones(coords.shape[0]),
                       coords['y'],coords['x']),axis =1)
    all_dots.append(newloc)
spots_caruby = np.concatenate(all_dots)
# Out:
# WARNING: QMainWindow::saveState(): 'objectName' not set for QDockWidget 0x564c2237e680 ';

# %%
f_igfp = pd.read_hdf('/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/spots_igfp_good.h5')
f_caruby = pd.read_hdf('/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/spots_caru3_good.h5')
f_caruby ['x'] = f_caruby ['x']*0.108
f_caruby ['y'] = f_caruby ['y']*0.108
f_igfp['x'] = f_igfp['x']*0.108
f_igfp['y'] = f_igfp['y']*0.108

# %%
spots['x'] = spots['x']*0.108
spots['y'] = spots['y']*0.108

# %%
blue
# Out:
# dask.array<getitem, shape=(122, 5120, 9216), dtype=uint16, chunksize=(1, 1024, 1024), chunktype=numpy.ndarray>

# %%
print('Number of iGFP particles at time 0:',len(f_igfp[f_igfp.frame == 0]))
print('Number of CA-mRuby3 particles at time 0:',len(f_caruby[f_caruby.frame == 0]))
print('Number of cells:',len(spots)/122)
import time
# Out:
# Number of iGFP particles at time 0: 55710
# Number of CA-mRuby3 particles at time 0: 41533
# Number of cells: 1885.9262295081967

# %%
v = napari.Viewer(ndisplay=2)
v.add_image(igfp,
            # rgb=True,
            contrast_limits=[0,2**16-1],
            blending='additive',
            colormap='green',
            name='iGFP',#, is_pyramid=False
            scale=((0.108,0.108))
                 )
v.add_image(red,
            # rgb=True,
            contrast_limits=[0,2**16-1],
            blending='additive',
            colormap='red',
            name='CA-mRuby3',#, is_pyramid=False
            scale=((0.108,0.108))
                 )

v.text_overlay.visible = True
v.text_overlay.text = "Day:{0}".format(time.strftime('%d %H:%M:%S',time.gmtime(timelist[0])))

v.dims.events.current_step.connect(update_slider)

v.add_points(spots,face_color='white',opacity=0.5,size=1.5)

v.add_points(spots_igfp,face_color='green',opacity=0.5,size=0.4)
v.add_points(spots_caruby,face_color='red',opacity=0.5,size=0.4)
# Out:
# <Points layer 'spots_caruby' at 0x7f4175fb4f10>

# %%
v.text_overlay.font_size = 20
# Out:
# Rendering frame  1 of 281
# Rendering frame  2 of 281
# Rendering frame  3 of 281
# Rendering frame  4 of 281
# Rendering frame  5 of 281
# Rendering frame  6 of 281
# Rendering frame  7 of 281
# Rendering frame  8 of 281
# Rendering frame  9 of 281
# Rendering frame  10 of 281
# Rendering frame  11 of 281
# Rendering frame  12 of 281
# Rendering frame  13 of 281
# Rendering frame  14 of 281
# Rendering frame  15 of 281
# Rendering frame  16 of 281
# Rendering frame  17 of 281
# Rendering frame  18 of 281
# Rendering frame  19 of 281
# Rendering frame  20 of 281
# Rendering frame  21 of 281
# Rendering frame  22 of 281
# Rendering frame  23 of 281
# Rendering frame  24 of 281
# Rendering frame  25 of 281
# Rendering frame  26 of 281
# Rendering frame  27 of 281
# Rendering frame  28 of 281
# Rendering frame  29 of 281
# Rendering frame  30 of 281
# Rendering frame  31 of 281
# Rendering frame  32 of 281
# Rendering frame  33 of 281
# Rendering frame  34 of 281
# Rendering frame  35 of 281
# Rendering frame  36 of 281
# Rendering frame  37 of 281
# Rendering frame  38 of 281
# Rendering frame  39 of 281
# Rendering frame  40 of 281
# Rendering frame  41 of 281
# Rendering frame  42 of 281
# Rendering frame  43 of 281
# Rendering frame  44 of 281
# Rendering frame  45 of 281
# Rendering frame  46 of 281
# Rendering frame  47 of 281
# Rendering frame  48 of 281
# Rendering frame  49 of 281
# Rendering frame  50 of 281
# Rendering frame  51 of 281
# Rendering frame  52 of 281
# Rendering frame  53 of 281
# Rendering frame  54 of 281
# Rendering frame  55 of 281
# Rendering frame  56 of 281
# Rendering frame  57 of 281
# Rendering frame  58 of 281
# Rendering frame  59 of 281
# Rendering frame  60 of 281
# Rendering frame  61 of 281
# Rendering frame  62 of 281
# Rendering frame  63 of 281
# Rendering frame  64 of 281
# Rendering frame  65 of 281
# Rendering frame  66 of 281
# Rendering frame  67 of 281
# Rendering frame  68 of 281
# Rendering frame  69 of 281
# Rendering frame  70 of 281
# Rendering frame  71 of 281
# Rendering frame  72 of 281
# Rendering frame  73 of 281
# Rendering frame  74 of 281
# Rendering frame  75 of 281
# Rendering frame  76 of 281
# Rendering frame  77 of 281
# Rendering frame  78 of 281
# Rendering frame  79 of 281
# Rendering frame  80 of 281
# Rendering frame  81 of 281
# Rendering frame  82 of 281
# Rendering frame  83 of 281
# Rendering frame  84 of 281
# Rendering frame  85 of 281
# Rendering frame  86 of 281
# Rendering frame  87 of 281
# Rendering frame  88 of 281
# Rendering frame  89 of 281
# Rendering frame  90 of 281
# Rendering frame  91 of 281
# Rendering frame  92 of 281
# Rendering frame  93 of 281
# Rendering frame  94 of 281
# Rendering frame  95 of 281
# Rendering frame  96 of 281
# Rendering frame  97 of 281
# Rendering frame  98 of 281
# Rendering frame  99 of 281
# Rendering frame  100 of 281
# Rendering frame  101 of 281
# Rendering frame  102 of 281
# Rendering frame  103 of 281
# Rendering frame  104 of 281
# Rendering frame  105 of 281
# Rendering frame  106 of 281
# Rendering frame  107 of 281
# Rendering frame  108 of 281
# Rendering frame  109 of 281
# Rendering frame  110 of 281
# Rendering frame  111 of 281
# Rendering frame  112 of 281
# Rendering frame  113 of 281
# Rendering frame  114 of 281
# Rendering frame  115 of 281
# Rendering frame  116 of 281
# Rendering frame  117 of 281
# Rendering frame  118 of 281
# Rendering frame  119 of 281
# Rendering frame  120 of 281
# Rendering frame  121 of 281
# Rendering frame  122 of 281
# Rendering frame  123 of 281
# Rendering frame  124 of 281
# Rendering frame  125 of 281
# Rendering frame  126 of 281
# Rendering frame  127 of 281
# Rendering frame  128 of 281
# Rendering frame  129 of 281
# Rendering frame  130 of 281
# Rendering frame  131 of 281
# Rendering frame  132 of 281
# Rendering frame  133 of 281
# Rendering frame  134 of 281
# Rendering frame  135 of 281
# Rendering frame  136 of 281
# Rendering frame  137 of 281
# Rendering frame  138 of 281
# Rendering frame  139 of 281
# Rendering frame  140 of 281
# Rendering frame  141 of 281
# Rendering frame  142 of 281
# Rendering frame  143 of 281
# Rendering frame  144 of 281
# Rendering frame  145 of 281
# Rendering frame  146 of 281
# Rendering frame  147 of 281
# Rendering frame  148 of 281
# Rendering frame  149 of 281
# Rendering frame  150 of 281
# Rendering frame  151 of 281
# Rendering frame  152 of 281
# Rendering frame  153 of 281
# Rendering frame  154 of 281
# Rendering frame  155 of 281
# Rendering frame  156 of 281
# Rendering frame  157 of 281
# Rendering frame  158 of 281
# Rendering frame  159 of 281
# Rendering frame  160 of 281
# Rendering frame  161 of 281
# Rendering frame  162 of 281
# Rendering frame  163 of 281
# Rendering frame  164 of 281
# Rendering frame  165 of 281
# Rendering frame  166 of 281
# Rendering frame  167 of 281
# Rendering frame  168 of 281
# Rendering frame  169 of 281
# Rendering frame  170 of 281
# Rendering frame  171 of 281
# Rendering frame  172 of 281
# Rendering frame  173 of 281
# Rendering frame  174 of 281
# Rendering frame  175 of 281
# Rendering frame  176 of 281
# Rendering frame  177 of 281
# Rendering frame  178 of 281
# Rendering frame  179 of 281
# Rendering frame  180 of 281
# Rendering frame  181 of 281
# Rendering frame  182 of 281
# Rendering frame  183 of 281
# Rendering frame  184 of 281
# Rendering frame  185 of 281
# Rendering frame  186 of 281
# Rendering frame  187 of 281
# Rendering frame  188 of 281
# Rendering frame  189 of 281
# Rendering frame  190 of 281
# Rendering frame  191 of 281
# Rendering frame  192 of 281
# Rendering frame  193 of 281
# Rendering frame  194 of 281
# Rendering frame  195 of 281
# Rendering frame  196 of 281
# Rendering frame  197 of 281
# Rendering frame  198 of 281
# Rendering frame  199 of 281
# Rendering frame  200 of 281
# Rendering frame  201 of 281
# Rendering frame  202 of 281
# Rendering frame  203 of 281
# Rendering frame  204 of 281
# Rendering frame  205 of 281
# Rendering frame  206 of 281
# Rendering frame  207 of 281
# Rendering frame  208 of 281
# Rendering frame  209 of 281
# Rendering frame  210 of 281
# Rendering frame  211 of 281
# Rendering frame  212 of 281
# Rendering frame  213 of 281
# Rendering frame  214 of 281
# Rendering frame  215 of 281
# Rendering frame  216 of 281
# Rendering frame  217 of 281
# Rendering frame  218 of 281
# Rendering frame  219 of 281
# Rendering frame  220 of 281
# Rendering frame  221 of 281
# Rendering frame  222 of 281
# Rendering frame  223 of 281
# Rendering frame  224 of 281
# Rendering frame  225 of 281
# Rendering frame  226 of 281
# Rendering frame  227 of 281
# Rendering frame  228 of 281
# Rendering frame  229 of 281
# Rendering frame  230 of 281
# Rendering frame  231 of 281
# Rendering frame  232 of 281
# Rendering frame  233 of 281
# Rendering frame  234 of 281
# Rendering frame  235 of 281
# Rendering frame  236 of 281
# Rendering frame  237 of 281
# Rendering frame  238 of 281
# Rendering frame  239 of 281
# Rendering frame  240 of 281
# Rendering frame  241 of 281
# Rendering frame  242 of 281
# Rendering frame  243 of 281
# Rendering frame  244 of 281
# Rendering frame  245 of 281
# Rendering frame  246 of 281
# Rendering frame  247 of 281
# Rendering frame  248 of 281
# Rendering frame  249 of 281
# Rendering frame  250 of 281
# Rendering frame  251 of 281
# Rendering frame  252 of 281
# Rendering frame  253 of 281
# Rendering frame  254 of 281
# Rendering frame  255 of 281
# Rendering frame  256 of 281
# Rendering frame  257 of 281
# Rendering frame  258 of 281
# Rendering frame  259 of 281
# Rendering frame  260 of 281
# Rendering frame  261 of 281
# Rendering frame  262 of 281
# Rendering frame  263 of 281
# Rendering frame  264 of 281
# Rendering frame  265 of 281
# Rendering frame  266 of 281
# Rendering frame  267 of 281
# Rendering frame  268 of 281
# Rendering frame  269 of 281
# Rendering frame  270 of 281
# Rendering frame  271 of 281
# Rendering frame  272 of 281
# Rendering frame  273 of 281
# Rendering frame  274 of 281
# Rendering frame  275 of 281
# Rendering frame  276 of 281
# Rendering frame  277 of 281
# Rendering frame  278 of 281
# Rendering frame  279 of 281
# Rendering frame  280 of 281
# Rendering frame  281 of 281
# Rendering frame  1 of 281
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (1352, 891) to (1360, 896) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# Rendering frame  2 of 281
# Rendering frame  3 of 281
# Rendering frame  4 of 281
# Rendering frame  5 of 281
# Rendering frame  6 of 281
# Rendering frame  7 of 281
# Rendering frame  8 of 281
# Rendering frame  9 of 281
# Rendering frame  10 of 281
# Rendering frame  11 of 281
# Rendering frame  12 of 281
# Rendering frame  13 of 281
# Rendering frame  14 of 281
# Rendering frame  15 of 281
# Rendering frame  16 of 281
# Rendering frame  17 of 281
# Rendering frame  18 of 281
# Rendering frame  19 of 281
# Rendering frame  20 of 281
# Rendering frame  21 of 281
# Rendering frame  22 of 281
# Rendering frame  23 of 281
# Rendering frame  24 of 281
# Rendering frame  25 of 281
# Rendering frame  26 of 281
# Rendering frame  27 of 281
# Rendering frame  28 of 281
# Rendering frame  29 of 281
# Rendering frame  30 of 281
# Rendering frame  31 of 281
# Rendering frame  32 of 281
# Rendering frame  33 of 281
# Rendering frame  34 of 281
# Rendering frame  35 of 281
# Rendering frame  36 of 281
# Rendering frame  37 of 281
# Rendering frame  38 of 281
# Rendering frame  39 of 281
# Rendering frame  40 of 281
# Rendering frame  41 of 281
# Rendering frame  42 of 281
# Rendering frame  43 of 281
# Rendering frame  44 of 281
# Rendering frame  45 of 281
# Rendering frame  46 of 281
# Rendering frame  47 of 281
# Rendering frame  48 of 281
# Rendering frame  49 of 281
# Rendering frame  50 of 281
# Rendering frame  51 of 281
# Rendering frame  52 of 281
# Rendering frame  53 of 281
# Rendering frame  54 of 281
# Rendering frame  55 of 281
# Rendering frame  56 of 281
# Rendering frame  57 of 281
# Rendering frame  58 of 281
# Rendering frame  59 of 281
# Rendering frame  60 of 281
# Rendering frame  61 of 281
# Rendering frame  62 of 281
# Rendering frame  63 of 281
# Rendering frame  64 of 281
# Rendering frame  65 of 281
# Rendering frame  66 of 281
# Rendering frame  67 of 281
# Rendering frame  68 of 281
# Rendering frame  69 of 281
# Rendering frame  70 of 281
# Rendering frame  71 of 281
# Rendering frame  72 of 281
# Rendering frame  73 of 281
# Rendering frame  74 of 281
# Rendering frame  75 of 281
# Rendering frame  76 of 281
# Rendering frame  77 of 281
# Rendering frame  78 of 281
# Rendering frame  79 of 281
# Rendering frame  80 of 281
# Rendering frame  81 of 281
# Rendering frame  82 of 281
# Rendering frame  83 of 281
# Rendering frame  84 of 281
# Rendering frame  85 of 281
# Rendering frame  86 of 281
# Rendering frame  87 of 281
# Rendering frame  88 of 281
# Rendering frame  89 of 281
# Rendering frame  90 of 281
# Rendering frame  91 of 281
# Rendering frame  92 of 281
# Rendering frame  93 of 281
# Rendering frame  94 of 281
# Rendering frame  95 of 281
# Rendering frame  96 of 281
# Rendering frame  97 of 281
# Rendering frame  98 of 281
# Rendering frame  99 of 281
# Rendering frame  100 of 281
# Rendering frame  101 of 281
# Rendering frame  102 of 281
# Rendering frame  103 of 281
# Rendering frame  104 of 281
# Rendering frame  105 of 281
# Rendering frame  106 of 281
# Rendering frame  107 of 281
# Rendering frame  108 of 281
# Rendering frame  109 of 281
# Rendering frame  110 of 281
# Rendering frame  111 of 281
# Rendering frame  112 of 281
# Rendering frame  113 of 281
# Rendering frame  114 of 281
# Rendering frame  115 of 281
# Rendering frame  116 of 281
# Rendering frame  117 of 281
# Rendering frame  118 of 281
# Rendering frame  119 of 281
# Rendering frame  120 of 281
# Rendering frame  121 of 281
# Rendering frame  122 of 281
# Rendering frame  123 of 281
# Rendering frame  124 of 281
# Rendering frame  125 of 281
# Rendering frame  126 of 281
# Rendering frame  127 of 281
# Rendering frame  128 of 281
# Rendering frame  129 of 281
# Rendering frame  130 of 281
# Rendering frame  131 of 281
# Rendering frame  132 of 281
# Rendering frame  133 of 281
# Rendering frame  134 of 281
# Rendering frame  135 of 281
# Rendering frame  136 of 281
# Rendering frame  137 of 281
# Rendering frame  138 of 281
# Rendering frame  139 of 281
# Rendering frame  140 of 281
# Rendering frame  141 of 281
# Rendering frame  142 of 281
# Rendering frame  143 of 281
# Rendering frame  144 of 281
# Rendering frame  145 of 281
# Rendering frame  146 of 281
# Rendering frame  147 of 281
# Rendering frame  148 of 281
# Rendering frame  149 of 281
# Rendering frame  150 of 281
# Rendering frame  151 of 281
# Rendering frame  152 of 281
# Rendering frame  153 of 281
# Rendering frame  154 of 281
# Rendering frame  155 of 281
# Rendering frame  156 of 281
# Rendering frame  157 of 281
# Rendering frame  158 of 281
# Rendering frame  159 of 281
# Rendering frame  160 of 281
# Rendering frame  161 of 281
# Rendering frame  162 of 281
# Rendering frame  163 of 281
# Rendering frame  164 of 281
# Rendering frame  165 of 281
# Rendering frame  166 of 281
# Rendering frame  167 of 281
# Rendering frame  168 of 281
# Rendering frame  169 of 281
# Rendering frame  170 of 281
# Rendering frame  171 of 281
# Rendering frame  172 of 281
# Rendering frame  173 of 281
# Rendering frame  174 of 281
# Rendering frame  175 of 281
# Rendering frame  176 of 281
# Rendering frame  177 of 281
# Rendering frame  178 of 281
# Rendering frame  179 of 281
# Rendering frame  180 of 281
# Rendering frame  181 of 281
# Rendering frame  182 of 281
# Rendering frame  183 of 281
# Rendering frame  184 of 281
# Rendering frame  185 of 281
# Rendering frame  186 of 281
# Rendering frame  187 of 281
# Rendering frame  188 of 281
# Rendering frame  189 of 281
# Rendering frame  190 of 281
# Rendering frame  191 of 281
# Rendering frame  192 of 281
# Rendering frame  193 of 281
# Rendering frame  194 of 281
# Rendering frame  195 of 281
# Rendering frame  196 of 281
# Rendering frame  197 of 281
# Rendering frame  198 of 281
# Rendering frame  199 of 281
# Rendering frame  200 of 281
# Rendering frame  201 of 281
# Rendering frame  202 of 281
# Rendering frame  203 of 281
# Rendering frame  204 of 281
# Rendering frame  205 of 281
# Rendering frame  206 of 281
# Rendering frame  207 of 281
# Rendering frame  208 of 281
# Rendering frame  209 of 281
# Rendering frame  210 of 281
# Rendering frame  211 of 281
# Rendering frame  212 of 281
# Rendering frame  213 of 281
# Rendering frame  214 of 281
# Rendering frame  215 of 281
# Rendering frame  216 of 281
# Rendering frame  217 of 281
# Rendering frame  218 of 281
# Rendering frame  219 of 281
# Rendering frame  220 of 281
# Rendering frame  221 of 281
# Rendering frame  222 of 281
# Rendering frame  223 of 281
# Rendering frame  224 of 281
# Rendering frame  225 of 281
# Rendering frame  226 of 281
# Rendering frame  227 of 281
# Rendering frame  228 of 281
# Rendering frame  229 of 281
# Rendering frame  230 of 281
# Rendering frame  231 of 281
# Rendering frame  232 of 281
# Rendering frame  233 of 281
# Rendering frame  234 of 281
# Rendering frame  235 of 281
# Rendering frame  236 of 281
# Rendering frame  237 of 281
# Rendering frame  238 of 281
# Rendering frame  239 of 281
# Rendering frame  240 of 281
# Rendering frame  241 of 281
# Rendering frame  242 of 281
# Rendering frame  243 of 281
# Rendering frame  244 of 281
# Rendering frame  245 of 281
# Rendering frame  246 of 281
# Rendering frame  247 of 281
# Rendering frame  248 of 281
# Rendering frame  249 of 281
# Rendering frame  250 of 281
# Rendering frame  251 of 281
# Rendering frame  252 of 281
# Rendering frame  253 of 281
# Rendering frame  254 of 281
# Rendering frame  255 of 281
# Rendering frame  256 of 281
# Rendering frame  257 of 281
# Rendering frame  258 of 281
# Rendering frame  259 of 281
# Rendering frame  260 of 281
# Rendering frame  261 of 281
# Rendering frame  262 of 281
# Rendering frame  263 of 281
# Rendering frame  264 of 281
# Rendering frame  265 of 281
# Rendering frame  266 of 281
# Rendering frame  267 of 281
# Rendering frame  268 of 281
# Rendering frame  269 of 281
# Rendering frame  270 of 281
# Rendering frame  271 of 281
# Rendering frame  272 of 281
# Rendering frame  273 of 281
# Rendering frame  274 of 281
# Rendering frame  275 of 281
# Rendering frame  276 of 281
# Rendering frame  277 of 281
# Rendering frame  278 of 281
# Rendering frame  279 of 281
# Rendering frame  280 of 281
# Rendering frame  281 of 281
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (1149, 780) to (1152, 784) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# Rendering frame  1 of 581
# Rendering frame  2 of 581
# Rendering frame  3 of 581
# Rendering frame  4 of 581
# Rendering frame  5 of 581
# Rendering frame  6 of 581
# Rendering frame  7 of 581
# Rendering frame  8 of 581
# Rendering frame  9 of 581
# Rendering frame  10 of 581
# Rendering frame  11 of 581
# Rendering frame  12 of 581
# Rendering frame  13 of 581
# Rendering frame  14 of 581
# Rendering frame  15 of 581
# Rendering frame  16 of 581
# Rendering frame  17 of 581
# Rendering frame  18 of 581
# Rendering frame  19 of 581
# Rendering frame  20 of 581
# Rendering frame  21 of 581
# Rendering frame  22 of 581
# Rendering frame  23 of 581
# Rendering frame  24 of 581
# Rendering frame  25 of 581
# Rendering frame  26 of 581
# Rendering frame  27 of 581
# Rendering frame  28 of 581
# Rendering frame  29 of 581
# Rendering frame  30 of 581
# Rendering frame  31 of 581
# Rendering frame  32 of 581
# Rendering frame  33 of 581
# Rendering frame  34 of 581
# Rendering frame  35 of 581
# Rendering frame  36 of 581
# Rendering frame  37 of 581
# Rendering frame  38 of 581
# Rendering frame  39 of 581
# Rendering frame  40 of 581
# Rendering frame  41 of 581
# Rendering frame  42 of 581
# Rendering frame  43 of 581
# Rendering frame  44 of 581
# Rendering frame  45 of 581
# Rendering frame  46 of 581
# Rendering frame  47 of 581
# Rendering frame  48 of 581
# Rendering frame  49 of 581
# Rendering frame  50 of 581
# Rendering frame  51 of 581
# Rendering frame  52 of 581
# Rendering frame  53 of 581
# Rendering frame  54 of 581
# Rendering frame  55 of 581
# Rendering frame  56 of 581
# Rendering frame  57 of 581
# Rendering frame  58 of 581
# Rendering frame  59 of 581
# Rendering frame  60 of 581
# Rendering frame  61 of 581
# Rendering frame  62 of 581
# Rendering frame  63 of 581
# Rendering frame  64 of 581
# Rendering frame  65 of 581
# Rendering frame  66 of 581
# Rendering frame  67 of 581
# Rendering frame  68 of 581
# Rendering frame  69 of 581
# Rendering frame  70 of 581
# Rendering frame  71 of 581
# Rendering frame  72 of 581
# Rendering frame  73 of 581
# Rendering frame  74 of 581
# Rendering frame  75 of 581
# Rendering frame  76 of 581
# Rendering frame  77 of 581
# Rendering frame  78 of 581
# Rendering frame  79 of 581
# Rendering frame  80 of 581
# Rendering frame  81 of 581
# Rendering frame  82 of 581
# Rendering frame  83 of 581
# Rendering frame  84 of 581
# Rendering frame  85 of 581
# Rendering frame  86 of 581
# Rendering frame  87 of 581
# Rendering frame  88 of 581
# Rendering frame  89 of 581
# Rendering frame  90 of 581
# Rendering frame  91 of 581
# Rendering frame  92 of 581
# Rendering frame  93 of 581
# Rendering frame  94 of 581
# Rendering frame  95 of 581
# Rendering frame  96 of 581
# Rendering frame  97 of 581
# Rendering frame  98 of 581
# Rendering frame  99 of 581
# Rendering frame  100 of 581
# Rendering frame  101 of 581
# Rendering frame  102 of 581
# Rendering frame  103 of 581
# Rendering frame  104 of 581
# Rendering frame  105 of 581
# Rendering frame  106 of 581
# Rendering frame  107 of 581
# Rendering frame  108 of 581
# Rendering frame  109 of 581
# Rendering frame  110 of 581
# Rendering frame  111 of 581
# Rendering frame  112 of 581
# Rendering frame  113 of 581
# Rendering frame  114 of 581
# Rendering frame  115 of 581
# Rendering frame  116 of 581
# Rendering frame  117 of 581
# Rendering frame  118 of 581
# Rendering frame  119 of 581
# Rendering frame  120 of 581
# Rendering frame  121 of 581
# Rendering frame  122 of 581
# Rendering frame  123 of 581
# Rendering frame  124 of 581
# Rendering frame  125 of 581
# Rendering frame  126 of 581
# Rendering frame  127 of 581
# Rendering frame  128 of 581
# Rendering frame  129 of 581
# Rendering frame  130 of 581
# Rendering frame  131 of 581
# Rendering frame  132 of 581
# Rendering frame  133 of 581
# Rendering frame  134 of 581
# Rendering frame  135 of 581
# Rendering frame  136 of 581
# Rendering frame  137 of 581
# Rendering frame  138 of 581
# Rendering frame  139 of 581
# Rendering frame  140 of 581
# Rendering frame  141 of 581
# Rendering frame  142 of 581
# Rendering frame  143 of 581
# Rendering frame  144 of 581
# Rendering frame  145 of 581
# Rendering frame  146 of 581
# Rendering frame  147 of 581
# Rendering frame  148 of 581
# Rendering frame  149 of 581
# Rendering frame  150 of 581
# Rendering frame  151 of 581
# Rendering frame  152 of 581
# Rendering frame  153 of 581
# Rendering frame  154 of 581
# Rendering frame  155 of 581
# Rendering frame  156 of 581
# Rendering frame  157 of 581
# Rendering frame  158 of 581
# Rendering frame  159 of 581
# Rendering frame  160 of 581
# Rendering frame  161 of 581
# Rendering frame  162 of 581
# Rendering frame  163 of 581
# Rendering frame  164 of 581
# Rendering frame  165 of 581
# Rendering frame  166 of 581
# Rendering frame  167 of 581
# Rendering frame  168 of 581
# Rendering frame  169 of 581
# Rendering frame  170 of 581
# Rendering frame  171 of 581
# Rendering frame  172 of 581
# Rendering frame  173 of 581
# Rendering frame  174 of 581
# Rendering frame  175 of 581
# Rendering frame  176 of 581
# Rendering frame  177 of 581
# Rendering frame  178 of 581
# Rendering frame  179 of 581
# Rendering frame  180 of 581
# Rendering frame  181 of 581
# Rendering frame  182 of 581
# Rendering frame  183 of 581
# Rendering frame  184 of 581
# Rendering frame  185 of 581
# Rendering frame  186 of 581
# Rendering frame  187 of 581
# Rendering frame  188 of 581
# Rendering frame  189 of 581
# Rendering frame  190 of 581
# Rendering frame  191 of 581
# Rendering frame  192 of 581
# Rendering frame  193 of 581
# Rendering frame  194 of 581
# Rendering frame  195 of 581
# Rendering frame  196 of 581
# Rendering frame  197 of 581
# Rendering frame  198 of 581
# Rendering frame  199 of 581
# Rendering frame  200 of 581
# Rendering frame  201 of 581
# Rendering frame  202 of 581
# Rendering frame  203 of 581
# Rendering frame  204 of 581
# Rendering frame  205 of 581
# Rendering frame  206 of 581
# Rendering frame  207 of 581
# Rendering frame  208 of 581
# Rendering frame  209 of 581
# Rendering frame  210 of 581
# Rendering frame  211 of 581
# Rendering frame  212 of 581
# Rendering frame  213 of 581
# Rendering frame  214 of 581
# Rendering frame  215 of 581
# Rendering frame  216 of 581
# Rendering frame  217 of 581
# Rendering frame  218 of 581
# Rendering frame  219 of 581
# Rendering frame  220 of 581
# Rendering frame  221 of 581
# Rendering frame  222 of 581
# Rendering frame  223 of 581
# Rendering frame  224 of 581
# Rendering frame  225 of 581
# Rendering frame  226 of 581
# Rendering frame  227 of 581
# Rendering frame  228 of 581
# Rendering frame  229 of 581
# Rendering frame  230 of 581
# Rendering frame  231 of 581
# Rendering frame  232 of 581
# Rendering frame  233 of 581
# Rendering frame  234 of 581
# Rendering frame  235 of 581
# Rendering frame  236 of 581
# Rendering frame  237 of 581
# Rendering frame  238 of 581
# Rendering frame  239 of 581
# Rendering frame  240 of 581
# Rendering frame  241 of 581
# Rendering frame  242 of 581
# Rendering frame  243 of 581
# Rendering frame  244 of 581
# Rendering frame  245 of 581
# Rendering frame  246 of 581
# Rendering frame  247 of 581
# Rendering frame  248 of 581
# Rendering frame  249 of 581
# Rendering frame  250 of 581
# Rendering frame  251 of 581
# Rendering frame  252 of 581
# Rendering frame  253 of 581
# Rendering frame  254 of 581
# Rendering frame  255 of 581
# Rendering frame  256 of 581
# Rendering frame  257 of 581
# Rendering frame  258 of 581
# Rendering frame  259 of 581
# Rendering frame  260 of 581
# Rendering frame  261 of 581
# Rendering frame  262 of 581
# Rendering frame  263 of 581
# Rendering frame  264 of 581
# Rendering frame  265 of 581
# Rendering frame  266 of 581
# Rendering frame  267 of 581
# Rendering frame  268 of 581
# Rendering frame  269 of 581
# Rendering frame  270 of 581
# Rendering frame  271 of 581
# Rendering frame  272 of 581
# Rendering frame  273 of 581
# Rendering frame  274 of 581
# Rendering frame  275 of 581
# Rendering frame  276 of 581
# Rendering frame  277 of 581
# Rendering frame  278 of 581
# Rendering frame  279 of 581
# Rendering frame  280 of 581
# Rendering frame  281 of 581
# Rendering frame  282 of 581
# Rendering frame  283 of 581
# Rendering frame  284 of 581
# Rendering frame  285 of 581
# Rendering frame  286 of 581
# Rendering frame  287 of 581
# Rendering frame  288 of 581
# Rendering frame  289 of 581
# Rendering frame  290 of 581
# Rendering frame  291 of 581
# Rendering frame  292 of 581
# Rendering frame  293 of 581
# Rendering frame  294 of 581
# Rendering frame  295 of 581
# Rendering frame  296 of 581
# Rendering frame  297 of 581
# Rendering frame  298 of 581
# Rendering frame  299 of 581
# Rendering frame  300 of 581
# Rendering frame  301 of 581
# Rendering frame  302 of 581
# Rendering frame  303 of 581
# Rendering frame  304 of 581
# Rendering frame  305 of 581
# Rendering frame  306 of 581
# Rendering frame  307 of 581
# Rendering frame  308 of 581
# Rendering frame  309 of 581
# Rendering frame  310 of 581
# Rendering frame  311 of 581
# Rendering frame  312 of 581
# Rendering frame  313 of 581
# Rendering frame  314 of 581
# Rendering frame  315 of 581
# Rendering frame  316 of 581
# Rendering frame  317 of 581
# Rendering frame  318 of 581
# Rendering frame  319 of 581
# Rendering frame  320 of 581
# Rendering frame  321 of 581
# Rendering frame  322 of 581
# Rendering frame  323 of 581
# Rendering frame  324 of 581
# Rendering frame  325 of 581
# Rendering frame  326 of 581
# Rendering frame  327 of 581
# Rendering frame  328 of 581
# Rendering frame  329 of 581
# Rendering frame  330 of 581
# Rendering frame  331 of 581
# Rendering frame  332 of 581
# Rendering frame  333 of 581
# Rendering frame  334 of 581
# Rendering frame  335 of 581
# Rendering frame  336 of 581
# Rendering frame  337 of 581
# Rendering frame  338 of 581
# Rendering frame  339 of 581
# Rendering frame  340 of 581
# Rendering frame  341 of 581
# Rendering frame  342 of 581
# Rendering frame  343 of 581
# Rendering frame  344 of 581
# Rendering frame  345 of 581
# Rendering frame  346 of 581
# Rendering frame  347 of 581
# Rendering frame  348 of 581
# Rendering frame  349 of 581
# Rendering frame  350 of 581
# Rendering frame  351 of 581
# Rendering frame  352 of 581
# Rendering frame  353 of 581
# Rendering frame  354 of 581
# Rendering frame  355 of 581
# Rendering frame  356 of 581
# Rendering frame  357 of 581
# Rendering frame  358 of 581
# Rendering frame  359 of 581
# Rendering frame  360 of 581
# Rendering frame  361 of 581
# Rendering frame  362 of 581
# Rendering frame  363 of 581
# Rendering frame  364 of 581
# Rendering frame  365 of 581
# Rendering frame  366 of 581
# Rendering frame  367 of 581
# Rendering frame  368 of 581
# Rendering frame  369 of 581
# Rendering frame  370 of 581
# Rendering frame  371 of 581
# Rendering frame  372 of 581
# Rendering frame  373 of 581
# Rendering frame  374 of 581
# Rendering frame  375 of 581
# Rendering frame  376 of 581
# Rendering frame  377 of 581
# Rendering frame  378 of 581
# Rendering frame  379 of 581
# Rendering frame  380 of 581
# Rendering frame  381 of 581
# Rendering frame  382 of 581
# Rendering frame  383 of 581
# Rendering frame  384 of 581
# Rendering frame  385 of 581
# Rendering frame  386 of 581
# Rendering frame  387 of 581
# Rendering frame  388 of 581
# Rendering frame  389 of 581
# Rendering frame  390 of 581
# Rendering frame  391 of 581
# Rendering frame  392 of 581
# Rendering frame  393 of 581
# Rendering frame  394 of 581
# Rendering frame  395 of 581
# Rendering frame  396 of 581
# Rendering frame  397 of 581
# Rendering frame  398 of 581
# Rendering frame  399 of 581
# Rendering frame  400 of 581
# Rendering frame  401 of 581
# Rendering frame  402 of 581
# Rendering frame  403 of 581
# Rendering frame  404 of 581
# Rendering frame  405 of 581
# Rendering frame  406 of 581
# Rendering frame  407 of 581
# Rendering frame  408 of 581
# Rendering frame  409 of 581
# Rendering frame  410 of 581
# Rendering frame  411 of 581
# Rendering frame  412 of 581
# Rendering frame  413 of 581
# Rendering frame  414 of 581
# Rendering frame  415 of 581
# Rendering frame  416 of 581
# Rendering frame  417 of 581
# Rendering frame  418 of 581
# Rendering frame  419 of 581
# Rendering frame  420 of 581
# Rendering frame  421 of 581
# Rendering frame  422 of 581
# Rendering frame  423 of 581
# Rendering frame  424 of 581
# Rendering frame  425 of 581
# Rendering frame  426 of 581
# Rendering frame  427 of 581
# Rendering frame  428 of 581
# Rendering frame  429 of 581
# Rendering frame  430 of 581
# Rendering frame  431 of 581
# Rendering frame  432 of 581
# Rendering frame  433 of 581
# Rendering frame  434 of 581
# Rendering frame  435 of 581
# Rendering frame  436 of 581
# Rendering frame  437 of 581
# Rendering frame  438 of 581
# Rendering frame  439 of 581
# Rendering frame  440 of 581
# Rendering frame  441 of 581
# Rendering frame  442 of 581
# Rendering frame  443 of 581
# Rendering frame  444 of 581
# Rendering frame  445 of 581
# Rendering frame  446 of 581
# Rendering frame  447 of 581
# Rendering frame  448 of 581
# Rendering frame  449 of 581
# Rendering frame  450 of 581
# Rendering frame  451 of 581
# Rendering frame  452 of 581
# Rendering frame  453 of 581
# Rendering frame  454 of 581
# Rendering frame  455 of 581
# Rendering frame  456 of 581
# Rendering frame  457 of 581
# Rendering frame  458 of 581
# Rendering frame  459 of 581
# Rendering frame  460 of 581
# Rendering frame  461 of 581
# Rendering frame  462 of 581
# Rendering frame  463 of 581
# Rendering frame  464 of 581
# Rendering frame  465 of 581
# Rendering frame  466 of 581
# Rendering frame  467 of 581
# Rendering frame  468 of 581
# Rendering frame  469 of 581
# Rendering frame  470 of 581
# Rendering frame  471 of 581
# Rendering frame  472 of 581
# Rendering frame  473 of 581
# Rendering frame  474 of 581
# Rendering frame  475 of 581
# Rendering frame  476 of 581
# Rendering frame  477 of 581
# Rendering frame  478 of 581
# Rendering frame  479 of 581
# Rendering frame  480 of 581
# Rendering frame  481 of 581
# Rendering frame  482 of 581
# Rendering frame  483 of 581
# Rendering frame  484 of 581
# Rendering frame  485 of 581
# Rendering frame  486 of 581
# Rendering frame  487 of 581
# Rendering frame  488 of 581
# Rendering frame  489 of 581
# Rendering frame  490 of 581
# Rendering frame  491 of 581
# Rendering frame  492 of 581
# Rendering frame  493 of 581
# Rendering frame  494 of 581
# Rendering frame  495 of 581
# Rendering frame  496 of 581
# Rendering frame  497 of 581
# Rendering frame  498 of 581
# Rendering frame  499 of 581
# Rendering frame  500 of 581
# Rendering frame  501 of 581
# Rendering frame  502 of 581
# Rendering frame  503 of 581
# Rendering frame  504 of 581
# Rendering frame  505 of 581
# Rendering frame  506 of 581
# Rendering frame  507 of 581
# Rendering frame  508 of 581
# Rendering frame  509 of 581
# Rendering frame  510 of 581
# Rendering frame  511 of 581
# Rendering frame  512 of 581
# Rendering frame  513 of 581
# Rendering frame  514 of 581
# Rendering frame  515 of 581
# Rendering frame  516 of 581
# Rendering frame  517 of 581
# Rendering frame  518 of 581
# Rendering frame  519 of 581
# Rendering frame  520 of 581
# Rendering frame  521 of 581
# Rendering frame  522 of 581
# Rendering frame  523 of 581
# Rendering frame  524 of 581
# Rendering frame  525 of 581
# Rendering frame  526 of 581
# Rendering frame  527 of 581
# Rendering frame  528 of 581
# Rendering frame  529 of 581
# Rendering frame  530 of 581
# Rendering frame  531 of 581
# Rendering frame  532 of 581
# Rendering frame  533 of 581
# Rendering frame  534 of 581
# Rendering frame  535 of 581
# Rendering frame  536 of 581
# Rendering frame  537 of 581
# Rendering frame  538 of 581
# Rendering frame  539 of 581
# Rendering frame  540 of 581
# Rendering frame  541 of 581
# Rendering frame  542 of 581
# Rendering frame  543 of 581
# Rendering frame  544 of 581
# Rendering frame  545 of 581
# Rendering frame  546 of 581
# Rendering frame  547 of 581
# Rendering frame  548 of 581
# Rendering frame  549 of 581
# Rendering frame  550 of 581
# Rendering frame  551 of 581
# Rendering frame  552 of 581
# Rendering frame  553 of 581
# Rendering frame  554 of 581
# Rendering frame  555 of 581
# Rendering frame  556 of 581
# Rendering frame  557 of 581
# Rendering frame  558 of 581
# Rendering frame  559 of 581
# Rendering frame  560 of 581
# Rendering frame  561 of 581
# Rendering frame  562 of 581
# Rendering frame  563 of 581
# Rendering frame  564 of 581
# Rendering frame  565 of 581
# Rendering frame  566 of 581
# Rendering frame  567 of 581
# Rendering frame  568 of 581
# Rendering frame  569 of 581
# Rendering frame  570 of 581
# Rendering frame  571 of 581
# Rendering frame  572 of 581
# Rendering frame  573 of 581
# Rendering frame  574 of 581
# Rendering frame  575 of 581
# Rendering frame  576 of 581
# Rendering frame  577 of 581
# Rendering frame  578 of 581
# Rendering frame  579 of 581
# Rendering frame  580 of 581
# Rendering frame  581 of 581
# WARNING: QMainWindow::saveState(): 'objectName' not set for QDockWidget 0x564c27eeebc0 ';

# %%
v.scale_bar.unit = 'um'

# %%
v.add_image(blue,
            # rgb=True,
            contrast_limits=[0,2**16-1],
            blending='additive',
            colormap='blue',
            name='mirfp670-LaminB10',#, is_pyramid=False
            scale=((0.108,0.108))
                 )
# Out:
# <Image layer 'mirfp670-LaminB10' at 0x7f4175ee3450>

# %%
from napari_animation import AnimationWidget

animation_widget = AnimationWidget(v)
v.window.add_dock_widget(animation_widget, area='right')

# %%
v.add_image(labels,
        blending='additive',
        colormap='jet',
        name='masks',#, is_pyramid=False
             )

# v.add_image(distance,
#         blending='additive',
#         colormap='jet',
#         name='distance',#, is_pyramid=False
#              )

# v.add_image(local_maxi,
#         blending='additive',
#         colormap='red',
#         name='maxi',#, is_pyramid=False
#              )


# v.add_image(labels,
#         blending='additive',
#         colormap='jet',
#         name='localmax',#, is_pyramid=False
#              )

# v.add_points(coords,face_color='white',opacity=0.5,size=15)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-10a40e9f0270> in <module>
# ----> 1 v.add_image(labels,
#       2         blending='additive',
#       3         colormap='jet',
#       4         name='masks',#, is_pyramid=False
#       5              )
#
# NameError: name 'labels' is not defined

# %% [markdown]
# ## Tracking
#
# Finally we use [trackpy](https://soft-matter.github.io/trackpy/v0.3.2/) to track the different nuclei. For that we just have to turn our time,x,y,z array into a Pandas dataframe and then call trackpy:

# %%
spots_pd = pd.DataFrame(spots,columns=['frame','y','x'])
traj = trackpy.link_df(spots_pd,search_range=65,memory=2)
with trackpy.PandasHDFStore('/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/TrajectoriesNuclei_65range.h5') as s:
    s.put(traj)
# Out:
# Frame 121: 2034 trajectories present.

# %% [markdown]
# We just exclude very short tracks to make the plot more readable:

# %%
all_traj = []
for ind in traj.particle.unique():
    curr_traj = traj[traj.particle==ind][['y','x']].values
    if curr_traj.shape[0]>5:
        all_traj.append(curr_traj)

# %% [markdown]
# And finally we add the trajectories to the plot as lines:

# %%
del(blue)
all8 = all.map_blocks(Libraries.convert16to8bits)
green = all8[:-3:3]
red = all8[1:-2:3]
blue = all8[2:-1:3]
green.shape

blue = blue.compute()
red = red.compute()
green = green.compute()

# %%
blue = rgb[2,...]
red = rgb[1,...]
green = rgb[0,...]

# %%
spots = pd.read_hdf('/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/Nuclei_spots3.h5')

# %%
filelist = glob.glob('/run/media/jmamede/Joao/CAruby/20210406mdm-WOWO/*ome.tiff')
filelist.sort()

metadata = pims.Bioformats(filelist[0]).metadata
metadata.PlaneDeltaT(0,0)
timelist = []
for i in range(metadata.PlaneCount(0)):
    timelist.append(metadata.PlaneDeltaT(0,i))

timelist = np.asarray(timelist)
timelist = timelist.reshape((metadata.PlaneCount(0)//3,metadata.ChannelCount(0)))
timelist.shape
timelist = timelist[:,0]
del(metadata)

import time
def update_slider(event):
    import time
    # only trigger if update comes from first axis (optional)
#     print('inside')
        #ind_lambda = viewer.dims.indices[0]
    ind_lambda = v.dims.current_step[0]
    timestrg = "Day: {0}".format(time.strftime('%d %H:%M:%S',time.gmtime(timelist[ind_lambda])))
    v.text_overlay.text = timestrg

# %%
# rmin = np.percentile(red,0.5)
# rmax = np.percentile(red,99.9)
# gmin = np.percentile(green,0.5)
# gmax = np.percentile(green,99.9)
# bmin = np.percentile(blue,0.5)
# bmax = np.percentile(blue,99.9)
# rmin = 1000
# rmax = 15000
# gmin = 1000
# gmax = 15000
# bmin = 1000
# bmax = 30000

# rmin = 0
# rmax = 255
# gmin = 0
# gmax = 255
# bmin = 0
# bmax = 255
v = napari.Viewer(ndisplay=2)
v.add_image(green,
            # rgb=True,
#             contrast_limits=[rmin,rmax],
            blending='additive',
            colormap='green',
            name='HIV-iGFP',#, is_pyramid=False
                 )
v.add_image(red,
#             contrast_limits=[gmin,gmax],
        blending='additive',
        colormap='red',
        name='CA-mRuby3',#, is_pyramid=False
             )
v.add_image(blue,
#             contrast_limits=[bmin,bmax],
        blending='additive',
        colormap='blue',
        name='Nucspot650',#, is_pyramid=False
             )

v.text_overlay.visible = True
v.text_overlay.text = "{0}".format(time.strftime('%d %H:%M:%S',time.gmtime(timelist[0])))
v.dims.events.current_step.connect(update_slider)

v.add_points(spots,face_color='white',opacity=0.5,size=15)
v.add_points(spots_igfp,face_color='green',opacity=0.5,size=3)
v.add_points(spots_caruby,face_color='red',opacity=0.5,size=3)
# v.add_shapes(all_traj, shape_type='path',edge_color='grey')
# Out:
# <Points layer 'spots_caruby' at 0x7fa7a8acd9d0>
# inside
# inside
# inside
# inside
# inside
# inside
# inside
# inside
