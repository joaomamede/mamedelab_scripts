# %%
# %matplotlib inline
import seaborn as sns
import pandas as pd
import numpy as np
# sns.set(font_scale = 2,style="ticks")
sns.set(font_scale = 2, style="whitegrid")

# %%
df = pd.read_hdf('/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/stored_data_trackpy_segm.h5')
# df_gfp  = pd.read_hdf('/home/jmamede/Data/D116N/stored_data_trackpy_gfp.h5')
# df_ruby = pd.read_hdf('/home/jmamede/Data/D116N/stored_data_trackpy_ruby.h5')
# df = df.replace(to_replace='optiR3-D117',value='mRuby3-D116N')
# df = df.replace(to_replace='sfGFPD117',value='sfGFP-D116N')
# df = df.replace(to_replace='mNeonD116',value='mNeonG-D116N')
# df = df.replace(to_replace='mWasabi-D116',value='mWasabi-D116N')
# df = df.replace(to_replace='D116',value='-D116N')

# %%
df.keys()
# Out:
# Index(['max membrane', 'mean membrane', 'stdev membrane', 'median membrane',
#        'COMY membrane', 'COMX membrane', 'Threshold membrane',
#        'Wavelength membrane', 'max Yfp', 'mean Yfp', 'stdev Yfp', 'median Yfp',
#        'COMY Yfp', 'COMX Yfp', 'Threshold Yfp', 'Wavelength Yfp', 'max PLA',
#        'mean PLA', 'stdev PLA', 'median PLA', 'COMY PLA', 'COMX PLA',
#        'Threshold PLA', 'Wavelength PLA', 'Filename', 'PlateRow', 'VisitP'],
#       dtype='object')

# %%
df.head()
# a.groupby('Protein')['Nb detections 1'].sum()
# Out:
#    max membrane  mean membrane  stdev membrane  median membrane  \
# 0          3326    2347.076923      567.926520           2168.0
# 1          1717    1387.384615      194.989758           1455.0
# 2          3485    2620.923077      561.841267           2796.0
# 3          3342    2308.230769      541.796322           2059.0
# 4          2378    1666.000000      370.136981           1666.0
#
#    COMY membrane  COMX membrane  Threshold membrane Wavelength membrane  \
# 0      61.046605     651.819186                 300            membrane
# 1      78.022788     680.041029                 300            membrane
# 2     108.109709     610.095210                 300            membrane
# 3     111.057387     673.961476                 300            membrane
# 4     116.022394     623.870487                 300            membrane
#
#    max Yfp     mean Yfp  ...     mean PLA    stdev PLA  median PLA  \
# 0     3494  2714.307692  ...  3388.846154  1082.517283      4095.0
# 1     4095  3340.384615  ...  2762.307692  1129.103687      2553.0
# 2     4095  2912.307692  ...  2057.384615  1160.027025      1515.0
# 3     4095  3580.384615  ...  3413.769231   839.329692      4095.0
# 4     4095  3077.461538  ...  3255.692308  1107.577216      4095.0
#
#      COMY PLA    COMX PLA Threshold PLA  Wavelength PLA  \
# 0   61.081512  651.917762           190             PLA
# 1   77.761376  680.128432           190             PLA
# 2  108.148994  610.036566           190             PLA
# 3  111.022060  674.109263           190             PLA
# 4  116.008081  624.008789           190             PLA
#
#                                             Filename  PlateRow  VisitP
# 0  /home/jmamede/Data/pqbp1/with Nina and laura/O...        E3      E3
# 1  /home/jmamede/Data/pqbp1/with Nina and laura/O...        E3      E3
# 2  /home/jmamede/Data/pqbp1/with Nina and laura/O...        E3      E3
# 3  /home/jmamede/Data/pqbp1/with Nina and laura/O...        E3      E3
# 4  /home/jmamede/Data/pqbp1/with Nina and laura/O...        E3      E3
#
# [5 rows x 27 columns]

# %%
df_gfp.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-5932d88b0981> in <module>
# ----> 1 df_gfp.head()
#
# NameError: name 'df_gfp' is not defined

# %%
df["Filename"].unique()
# Out:
# array(['/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/ninaplate5additionalwell_E3_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/ninaplate5additionalwell_E3a_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/ninaplate5additionalwell_E3b_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/ninaplate5additionalwell_E3d_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/ninaplate5additionalwell_E4_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/ninaplate5additionalwell_E4a_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/ninaplate5additionalwell_E4b_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/ninaplate5additionalwell_E4c_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/ninaplate5additionalwell_E4d_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/ninaplate5additionalwell_E4e_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/ninaplate5additionalwell_F3_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/ninaplate5additionalwell_F3a_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/ninaplate5additionalwell_F3c_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/ninaplate5additionalwell_F3d_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/ninaplate5additionalwell_F4_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/ninaplate5additionalwell_F4a_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/ninaplate5additionalwell_F4b_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/ninaplate5additionalwell_F4c_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_E3_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_E3a_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_E3b_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_E3c_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_E3d_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_E4_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_E4a_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_E4b_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_E4c_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_E4d_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_F3_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_F3a_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_F3b_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_F3c_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_F3d_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_F3e_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_F3f_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_F4_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_F4a_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_F4b_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_F4c_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_F4d_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_G3_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_G3a_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_G3b_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_G3c_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_G3d_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_G4_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_G4a_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_G4b_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_G4c_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_G4d_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_H3_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_H3a_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_H3b_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_H3c_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_H4_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_H4a_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_H4b_PRJ.ome.tiff',
#        '/home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_Series002_PRJ.ome.tiff'],
#       dtype=object)

# %%
# %matplotlib qt
# inquestion = df
# labels = ['lA01', 'lA02', 'lA03', 'lA04', 'lA05', 'lA06', 'lA07', 'lA08']
# subset = inquestion.loc[inquestion['VisitP'].isin(labels)]
subset=df
for well in subset['Filename'].unique():
    print(well,'\t',len(subset[subset['Filename'] == well]))
# Out:
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/ninaplate5additionalwell_E3_PRJ.ome.tiff 	 25
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/ninaplate5additionalwell_E3a_PRJ.ome.tiff 	 26
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/ninaplate5additionalwell_E3b_PRJ.ome.tiff 	 32
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/ninaplate5additionalwell_E3d_PRJ.ome.tiff 	 18
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/ninaplate5additionalwell_E4_PRJ.ome.tiff 	 22
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/ninaplate5additionalwell_E4a_PRJ.ome.tiff 	 35
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/ninaplate5additionalwell_E4b_PRJ.ome.tiff 	 53
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/ninaplate5additionalwell_E4c_PRJ.ome.tiff 	 40
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/ninaplate5additionalwell_E4d_PRJ.ome.tiff 	 43
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/ninaplate5additionalwell_E4e_PRJ.ome.tiff 	 78
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/ninaplate5additionalwell_F3_PRJ.ome.tiff 	 14
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/ninaplate5additionalwell_F3a_PRJ.ome.tiff 	 8
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/ninaplate5additionalwell_F3c_PRJ.ome.tiff 	 17
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/ninaplate5additionalwell_F3d_PRJ.ome.tiff 	 16
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/ninaplate5additionalwell_F4_PRJ.ome.tiff 	 112
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/ninaplate5additionalwell_F4a_PRJ.ome.tiff 	 45
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/ninaplate5additionalwell_F4b_PRJ.ome.tiff 	 49
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/ninaplate5additionalwell_F4c_PRJ.ome.tiff 	 34
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_E3_PRJ.ome.tiff 	 17
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_E3a_PRJ.ome.tiff 	 29
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_E3b_PRJ.ome.tiff 	 8
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_E3c_PRJ.ome.tiff 	 9
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_E3d_PRJ.ome.tiff 	 11
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_E4_PRJ.ome.tiff 	 37
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_E4a_PRJ.ome.tiff 	 47
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_E4b_PRJ.ome.tiff 	 56
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_E4c_PRJ.ome.tiff 	 35
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_E4d_PRJ.ome.tiff 	 79
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_F3_PRJ.ome.tiff 	 11
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_F3a_PRJ.ome.tiff 	 4
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_F3b_PRJ.ome.tiff 	 6
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_F3c_PRJ.ome.tiff 	 27
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_F3d_PRJ.ome.tiff 	 23
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_F3e_PRJ.ome.tiff 	 7
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_F3f_PRJ.ome.tiff 	 39
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_F4_PRJ.ome.tiff 	 50
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_F4a_PRJ.ome.tiff 	 45
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_F4b_PRJ.ome.tiff 	 68
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_F4c_PRJ.ome.tiff 	 142
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_F4d_PRJ.ome.tiff 	 162
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_G3_PRJ.ome.tiff 	 25
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_G3a_PRJ.ome.tiff 	 11
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_G3b_PRJ.ome.tiff 	 7
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_G3c_PRJ.ome.tiff 	 13
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_G3d_PRJ.ome.tiff 	 16
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_G4_PRJ.ome.tiff 	 8
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_G4a_PRJ.ome.tiff 	 5
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_G4b_PRJ.ome.tiff 	 14
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_G4c_PRJ.ome.tiff 	 26
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_G4d_PRJ.ome.tiff 	 10
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_H3_PRJ.ome.tiff 	 11
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_H3a_PRJ.ome.tiff 	 4
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_H3b_PRJ.ome.tiff 	 13
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_H3c_PRJ.ome.tiff 	 10
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_H4_PRJ.ome.tiff 	 2
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_H4a_PRJ.ome.tiff 	 1
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_H4b_PRJ.ome.tiff 	 4
# /home/jmamede/Data/pqbp1/with Nina and laura/OlderPlate/output/project_Series002_PRJ.ome.tiff 	 51
